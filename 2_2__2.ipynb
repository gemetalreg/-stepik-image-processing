# %%
# %matplotlib inline

# %%
from skimage.io import imread, imshow, imsave

# %%
img = imread('https://stepik.org/media/attachments/lesson/58181/tiger-color.png')

# %%
imshow(img)

# %%
from skimage import img_as_float

# %%
img_f = img_as_float(img)

# %%
img_neg = imread("https://stepik.org/media/attachments/lesson/58181/tiger-negative.png")

# %%
imshow(img_neg)

# %%
import numpy as np

# %%
img_f_neg = np.abs(img_f - 1)

# %%
imshow(img_f_neg)
